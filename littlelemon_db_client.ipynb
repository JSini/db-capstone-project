# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "root", password = "pwd", database='littlelemondb')

# %%
cursor = connection.cursor()

# %%
cursor.execute("show tables")

# %%
results = cursor.fetchall()
for result in results:
    print(result)
# Out:
# ('address',)
# ('bookings',)
# ('countries',)
# ('customers',)
# ('item_types',)
# ('menu',)
# ('menu_items',)
# ('order_deliveries',)
# ('orders',)
# ('ordersview',)
# ('staff_details',)

# %% [markdown]
# ####  Little Lemon need you to return specific details from your database. They require the full name and contact details for every customer that has placed an order greater than $60 for a promotional campaign.

# %%
query ="""select c.name, c.contact, c.email, o.total_cost
    from customers c inner join orders o on c.customer_id=o.customer_id
    where o.total_cost > 60;"""

cursor.execute(query)
print(cursor.column_names)
results = cursor.fetchall()
for result in results:
    print(result)
# Out:
# ('name', 'contact', 'email', 'total_cost')
# ('John Doe', '366-98200-12345', 'john.doe@email.in', Decimal('86.00'))
# ('Sophie Dubois', '+33 6 12 34 56 78', 's.dubois@service.fr', Decimal('237.00'))
# ('Li Wei', '+86 139 1234 5678', 'li.wei@workmail.com', Decimal('458.00'))
# ('Hans Müller', '+49 151 12345678', 'h.mueller@technik.de', Decimal('100.00'))
# ('James Wilson', '+1 212-555-0198', 'j.wilson88@provider.com', Decimal('200.00'))
# ('Yuki Tanaka', '+81 90-1234-5678', 'tanaka.y@net.jp', Decimal('250.00'))
# ('Fatima Sahar', '+971 50 123 4567', 'f.s@mail.com', Decimal('200.00'))
# ('Sophie Dubois', '+33 6 12 34 56 78', 's.dubois@service.fr', Decimal('250.00'))
# ('Isabella Rossi', '+39 333 123 4567', 'i.rossi@italia.it', Decimal('200.00'))
# ('Kwame Osei', '+233 24 123 4567', 'k.osei@africaonline.com', Decimal('250.00'))
# ('Hans Müller', '+49 151 12345678', 'h.mueller@technik.de', Decimal('100.00'))

# %%
## close connections
if connection.is_connected():
    cursor.close()
    print("cursor closed..")
    connection.close()
    print("connection closed..")
else:
    print("connection already closed...")
# Out:
# cursor closed..
# connection closed..
